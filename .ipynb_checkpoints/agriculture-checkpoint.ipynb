# %%
import os    
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
import tensorflow as tf
import pathlib
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,RandomFlip,Rescaling,Resizing,RandomRotation,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image_dataset_from_directory
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
train_dir = pathlib.Path('data/Train')

# %%
# class distribution
def Count_images(path):
    folder_image_count = {}
    for folder_name in os.listdir(path):
        folder_path = os.path.join(path, folder_name)
        
        # Ensure it's a directory (to skip any non-folder files)
        if os.path.isdir(folder_path):
            # Count the number of image files in this folder
            image_count = len([file for file in os.listdir(folder_path) if file.lower().endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp'))])
            folder_image_count[folder_name] = image_count


    for folder, count in folder_image_count.items():
        print(f"Folder '{folder}' has {count} images.")

# %%
Count_images(train_dir)
# Out:
# Folder 'American Bollworm on Cotton' has 56 images.
# Folder 'Anthracnose on Cotton' has 29 images.
# Folder 'Army worm' has 39 images.
# Folder 'bacterial_blight in Cotton' has 489 images.
# Folder 'Becterial Blight in Rice' has 1584 images.
# Folder 'bollworm on Cotton' has 21 images.
# Folder 'Brownspot' has 1640 images.
# Folder 'Common_Rust' has 1303 images.
# Folder 'Cotton Aphid' has 38 images.
# Folder 'cotton mealy bug' has 90 images.
# Folder 'cotton whitefly' has 54 images.
# Folder 'Flag Smut' has 179 images.
# Folder 'Gray_Leaf_Spot' has 574 images.
# Folder 'Healthy cotton' has 425 images.
# Folder 'Healthy Maize' has 1162 images.
# Folder 'Healthy Wheat' has 180 images.
# Folder 'Leaf Curl' has 417 images.
# Folder 'Leaf smut' has 40 images.
# Folder 'maize ear rot' has 112 images.
# Folder 'maize fall armyworm' has 107 images.
# Folder 'maize stem borer' has 95 images.
# Folder 'Mosaic sugarcane' has 462 images.
# Folder 'pink bollworm in cotton' has 24 images.
# Folder 'red cotton bug' has 69 images.
# Folder 'RedRot sugarcane' has 592 images.
# Folder 'RedRust sugarcane' has 75 images.
# Folder 'Rice Blast' has 1440 images.
# Folder 'Sugarcane Healthy' has 522 images.
# Folder 'thirps on  cotton' has 36 images.
# Folder 'Tungro' has 1308 images.
# Folder 'Wheat aphid' has 156 images.
# Folder 'Wheat black rust' has 161 images.
# Folder 'Wheat Brown leaf Rust' has 90 images.
# Folder 'Wheat leaf blight' has 143 images.
# Folder 'Wheat mite' has 154 images.
# Folder 'Wheat powdery mildew' has 142 images.
# Folder 'Wheat scab' has 95 images.
# Folder 'Wheat Stem fly' has 172 images.
# Folder 'Wheat___Yellow_Rust' has 92 images.
# Folder 'Wilt' has 419 images.
# Folder 'Yellow Rust Sugarcane' has 505 images.

# %%
# checking for unsupported files in tensorflow
def Verify_Images(path):
    for root, dirs, files in os.walk(path):
        for file in files:
            if not file.lower().endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp')):
                print(f"Unsupported file found and removed: {os.path.join(root, file)}")
                os.remove(os.path.join(root, file))

# %%
# checking for corrupt files
def Check_for_corrupt_files(path):
    for root, dirs, files in os.walk(path):
     for file in files:
        try:
            img_path = os.path.join(root, file)
            with Image.open(img_path) as img:
                img.verify() 
            return False
        except (IOError, SyntaxError) as e:
            print(f"Corrupt file found and removed: {img_path}")
            os.remove(img_path)
            return True

# %%
# removing non images
import imghdr

def Remove_non_images(path):
    image_extensions = [".png", ".jpg","jpeg"] 
    
    img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
    for filepath in pathlib.Path(path).rglob("*"):
        if filepath.suffix.lower() in image_extensions:
            img_type = imghdr.what(filepath)
            if img_type is None:
                os.remove(filepath)
                print(f"{filepath} is not an image removing...")
            elif img_type not in img_type_accepted_by_tf:
                os.remove(filepath)
                print(f"{filepath} is a {img_type}, not accepted by TensorFlow")

# %%
#main preprocessing directories images
import cv2
def check_images( s_dir, ext_list):
    bad_images=[]
    bad_ext=[]
    s_list= os.listdir(s_dir)
    for klass in s_list:
        klass_path=os.path.join (s_dir, klass)
        print ('processing class directory ', klass)
        if os.path.isdir(klass_path):
            file_list=os.listdir(klass_path)
            for f in file_list:               
                f_path=os.path.join (klass_path,f)
                index=f.rfind('.')
                ext=f[index+1:].lower()
                if ext not in ext_list:
                    print('file ', f_path, ' has an invalid extension ', ext)
                    bad_ext.append(f_path)
                if os.path.isfile(f_path):
                    try:
                        img=cv2.imread(f_path)
                        shape=img.shape
                    except:
                        print('file ', f_path, ' is not a valid image file')
                        bad_images.append(f_path)
                else:
                    print('*** fatal error, you a sub directory ', f, ' in class directory ', klass)
        else:
            print ('*** WARNING*** you have files in ', s_dir, ' it should only contain sub directories')
    return bad_images, bad_ext

# %%
# 
good_exts=['jpg', 'png', 'jpeg', 'gif', 'bmp' ] # list of acceptable extensions
bad_file_list, bad_ext_list=check_images(train_dir, good_exts)

if len(bad_file_list) !=0:
    print('improper image files are listed below')
    for i in range (len(bad_file_list)):
        print (bad_file_list[i])
else:
    print(' no improper image files were found')
# Out:
# processing class directory  American Bollworm on Cotton
# processing class directory  Anthracnose on Cotton
# processing class directory  Army worm
# processing class directory  bacterial_blight in Cotton
# processing class directory  Becterial Blight in Rice
# processing class directory  bollworm on Cotton
# processing class directory  Brownspot
# processing class directory  Common_Rust
# processing class directory  Cotton Aphid
# processing class directory  cotton mealy bug
# processing class directory  cotton whitefly
# processing class directory  Flag Smut
# processing class directory  Gray_Leaf_Spot
# processing class directory  Healthy cotton
# processing class directory  Healthy Maize
# processing class directory  Healthy Wheat
# processing class directory  Leaf Curl
# processing class directory  Leaf smut
# processing class directory  maize ear rot
# processing class directory  maize fall armyworm
# processing class directory  maize stem borer
# processing class directory  Mosaic sugarcane
# processing class directory  pink bollworm in cotton
# processing class directory  red cotton bug
# processing class directory  RedRot sugarcane
# processing class directory  RedRust sugarcane
# processing class directory  Rice Blast
# processing class directory  Sugarcane Healthy
# processing class directory  thirps on  cotton
# processing class directory  Tungro
# processing class directory  Wheat aphid
# processing class directory  Wheat black rust
# processing class directory  Wheat Brown leaf Rust
# processing class directory  Wheat leaf blight
# processing class directory  Wheat mite
# processing class directory  Wheat powdery mildew
# processing class directory  Wheat scab
# processing class directory  Wheat Stem fly
# processing class directory  Wheat___Yellow_Rust
# processing class directory  Wilt
# processing class directory  Yellow Rust Sugarcane
#  no improper image files were found

# %%
for file_path in bad_file_list:
   if os.path.exists(file_path):
    os.remove(file_path)
    print(f"{file_path} has been deleted.")
   else:
    print(f"{file_path} does not exist.")

# %%
# removing non images from the train dataset
Remove_non_images(train_dir)

# %%
# removing non images from the validation dataset
Remove_non_images(validation_dir)

# %%
# verifying train data
Verify_Images(train_dir)

# %%
# verify validation data
Verify_Images(validation_dir)

# %%
# removing corrupt files in train data
Check_for_corrupt_files(train_dir)
# Out:
# False

# %%
train_dataset = image_dataset_from_directory(train_dir,
                                             image_size=(224, 224),
                                             batch_size=32,
                                             label_mode="categorical",
                                             validation_split=0.2,    
                                             subset="training",
                                             seed=123
                                            )
# Out:
# Found 15291 files belonging to 41 classes.
# Using 12233 files for training.

# %%
validation_dataset = image_dataset_from_directory(train_dir,
                                                  image_size=(224,224),
                                                  batch_size=32,
                                                  label_mode="categorical",
                                                  validation_split=0.2,    
                                                  subset="validation",
                                                  seed=123
                                                 )
# Out:
# Found 15291 files belonging to 41 classes.
# Using 3058 files for validation.

# %%
# creating test data for evaluating the model

val_images,val_labels = zip(*[(x,y) for x,y in validation_dataset.unbatch()])
val_images,test_images,val_labels,test_labels = train_test_split(val_images,val_labels,test_size=0.5,random_state=42);

new_validation_dataset = tf.data.Dataset.from_tensor_slices((val_images,val_labels)).batch(32)
test_dataset = tf.data.Dataset.from_tensor_slices((test_images,test_labels)).batch(32)

# %%
print(f"new validation dataset length {len(new_validation_dataset)} and test data length {len(test_dataset)}")
# Out:
# new validation dataset length 48 and test data length 48

# %%
class_names=train_dataset.class_names

# %%
def Plot_images(dataset,num):
    plt.figure(figsize=(10,10))
    for images,labels in dataset.take(1):
        for i in range(num):
            ax = plt.subplot(3, 3 ,i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            # print(np.argmax(labels[i]))
            plt.title(class_names[np.argmax(labels[i])])
            plt.axis("off")
        plt.show()

# %%
Plot_images(train_dataset,9)

# %%
# validation dataset
Plot_images(validation_dataset,9)

# %%
Plot_images(test_dataset,9)

# %%
num_classes = len(class_names)
Batch_size=32

image_height=224
image_width=224

input_shape=(Batch_size,image_height,image_width,3)

model = Sequential()

model.add(Resizing(image_height,image_width))
model.add(Rescaling(1.0/255))
model.add(RandomFlip('horizontal_and_vertical'))
model.add(RandomRotation(0.2))
model.add(Conv2D(32,(3,3),activation='relu',input_shape=input_shape))
model.add(MaxPooling2D())
model.add(Dropout(0.2))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(num_classes,activation='softmax'))

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing_1 (Resizing)       (32, 224, 224, 3)         0
#
#  rescaling_1 (Rescaling)     (32, 224, 224, 3)         0
#
#  random_flip_1 (RandomFlip)  (32, 224, 224, 3)         0
#
#  random_rotation_1 (RandomRo  (32, 224, 224, 3)        0
#  tation)
#
#  conv2d_4 (Conv2D)           (32, 222, 222, 32)        896
#
#  max_pooling2d_4 (MaxPooling  (32, 111, 111, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (32, 111, 111, 32)        0
#
#  conv2d_5 (Conv2D)           (32, 109, 109, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (32, 54, 54, 64)         0
#  2D)
#
#  conv2d_6 (Conv2D)           (32, 52, 52, 64)          36928
#
#  max_pooling2d_6 (MaxPooling  (32, 26, 26, 64)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (32, 24, 24, 64)          36928
#
#  max_pooling2d_7 (MaxPooling  (32, 12, 12, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (32, 9216)                0
#
#  dense_2 (Dense)             (32, 128)                 1179776
#
#  dense_3 (Dense)             (32, 41)                  5289
#
# =================================================================
# Total params: 1,278,313
# Trainable params: 1,278,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=[ 'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')])

# %%
model = model.fit(train_dataset,
                    epochs=15,
                    steps_per_epoch=len(train_dataset),
                    batch_size=32,
                    validation_data=validation_dataset,
                    validation_steps=len(validation_dataset))
# Out:
# Epoch 1/15
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 383/383 [==============================] - 301s 773ms/step - loss: 2.2194 - accuracy: 0.4091 - precision: 0.7969 - recall: 0.2159 - val_loss: 1.8418 - val_accuracy: 0.4918 - val_precision: 0.7055 - val_recall: 0.3407
# Epoch 2/15
# 383/383 [==============================] - 329s 859ms/step - loss: 1.4570 - accuracy: 0.6044 - precision: 0.8239 - recall: 0.4574 - val_loss: 1.3505 - val_accuracy: 0.6370 - val_precision: 0.8197 - val_recall: 0.4846
# Epoch 3/15
# 383/383 [==============================] - 338s 881ms/step - loss: 1.1764 - accuracy: 0.6857 - precision: 0.8496 - recall: 0.5681 - val_loss: 1.1585 - val_accuracy: 0.6851 - val_precision: 0.8594 - val_recall: 0.5517
# Epoch 4/15
# 383/383 [==============================] - 335s 873ms/step - loss: 0.9776 - accuracy: 0.7387 - precision: 0.8708 - recall: 0.6446 - val_loss: 1.1083 - val_accuracy: 0.6995 - val_precision: 0.8358 - val_recall: 0.6024
# Epoch 5/15
# 383/383 [==============================] - 341s 890ms/step - loss: 0.8158 - accuracy: 0.7753 - precision: 0.8871 - recall: 0.7029 - val_loss: 0.8826 - val_accuracy: 0.7685 - val_precision: 0.8767 - val_recall: 0.6929
# Epoch 6/15
# 383/383 [==============================] - 362s 943ms/step - loss: 0.7162 - accuracy: 0.8022 - precision: 0.8967 - recall: 0.7414 - val_loss: 0.8154 - val_accuracy: 0.7927 - val_precision: 0.8820 - val_recall: 0.7211
# Epoch 7/15
# 383/383 [==============================] - 377s 984ms/step - loss: 0.6114 - accuracy: 0.8305 - precision: 0.9107 - recall: 0.7806 - val_loss: 0.7111 - val_accuracy: 0.8143 - val_precision: 0.8929 - val_recall: 0.7659
# Epoch 8/15
# 383/383 [==============================] - 335s 872ms/step - loss: 0.5450 - accuracy: 0.8500 - precision: 0.9176 - recall: 0.8021 - val_loss: 0.7560 - val_accuracy: 0.8005 - val_precision: 0.8717 - val_recall: 0.7685
# Epoch 9/15
# 383/383 [==============================] - 312s 814ms/step - loss: 0.5209 - accuracy: 0.8538 - precision: 0.9212 - recall: 0.8137 - val_loss: 0.7645 - val_accuracy: 0.8002 - val_precision: 0.9024 - val_recall: 0.7410
# Epoch 10/15
# 383/383 [==============================] - 324s 845ms/step - loss: 0.4630 - accuracy: 0.8680 - precision: 0.9271 - recall: 0.8306 - val_loss: 0.7141 - val_accuracy: 0.8195 - val_precision: 0.8951 - val_recall: 0.7783
# Epoch 11/15
# 383/383 [==============================] - 314s 819ms/step - loss: 0.4463 - accuracy: 0.8728 - precision: 0.9284 - recall: 0.8372 - val_loss: 0.7004 - val_accuracy: 0.8185 - val_precision: 0.8883 - val_recall: 0.7773
# Epoch 12/15
# 383/383 [==============================] - 321s 838ms/step - loss: 0.4101 - accuracy: 0.8819 - precision: 0.9317 - recall: 0.8502 - val_loss: 0.7059 - val_accuracy: 0.8188 - val_precision: 0.8924 - val_recall: 0.7731
# Epoch 13/15
# 383/383 [==============================] - 316s 823ms/step - loss: 0.3743 - accuracy: 0.8908 - precision: 0.9396 - recall: 0.8602 - val_loss: 0.6967 - val_accuracy: 0.8303 - val_precision: 0.8860 - val_recall: 0.8054
# Epoch 14/15
# 383/383 [==============================] - 316s 823ms/step - loss: 0.3474 - accuracy: 0.8965 - precision: 0.9385 - recall: 0.8692 - val_loss: 0.6904 - val_accuracy: 0.8349 - val_precision: 0.8893 - val_recall: 0.8116
# Epoch 15/15
# 383/383 [==============================] - 322s 839ms/step - loss: 0.3411 - accuracy: 0.8997 - precision: 0.9386 - recall: 0.8749 - val_loss: 0.6337 - val_accuracy: 0.8450 - val_precision: 0.9004 - val_recall: 0.8218

# %%
plt.figure(figsize=(20,20))
pd.DataFrame(model.history).plot()
plt.show()

# %%
pd.DataFrame(model.history)
# Out:
#         loss  accuracy  precision    recall  val_loss  val_accuracy  \
# 0   2.219426  0.409057   0.796922  0.215891  1.841795      0.491825
# 1   1.456976  0.604431   0.823885  0.457369  1.350517      0.637018
# 2   1.176420  0.685686   0.849615  0.568054  1.158521      0.685088
# 3   0.977647  0.738739   0.870804  0.644650  1.108330      0.699477
# 4   0.815802  0.775280   0.887123  0.702853  0.882592      0.768476
# 5   0.716232  0.802174   0.896688  0.741437  0.815372      0.792675
# 6   0.611364  0.830459   0.910730  0.780593  0.711055      0.814258
# 7   0.544957  0.849996   0.917610  0.802093  0.756038      0.800523
# 8   0.520898  0.853756   0.921240  0.813701  0.764470      0.800196
# 9   0.463029  0.867980   0.927099  0.830622  0.714066      0.819490
# 10  0.446253  0.872803   0.928384  0.837162  0.700432      0.818509
# 11  0.410147  0.881877   0.931733  0.850159  0.705871      0.818836
# 12  0.374325  0.890787   0.939554  0.860214  0.696723      0.830281
# 13  0.347409  0.896509   0.938482  0.869206  0.690440      0.834859
# 14  0.341087  0.899698   0.938613  0.874928  0.633687      0.844997
#
#     val_precision  val_recall
# 0        0.705484    0.340746
# 1        0.819690    0.484630
# 2        0.859399    0.551668
# 3        0.835753    0.602354
# 4        0.876707    0.692937
# 5        0.882000    0.721060
# 6        0.892871    0.765860
# 7        0.871662    0.768476
# 8        0.902429    0.741007
# 9        0.895073    0.778286
# 10       0.888266    0.777305
# 11       0.892412    0.773054
# 12       0.885971    0.805428
# 13       0.889287    0.811642
# 14       0.900394    0.821779
